# %%
import panel as pn
import geoviews as gv
import holoviews as hv

# %%
pn.extension()

# %%
# Load your results
routes_gdf = gpd.read_file('outputs/routes.geojson')

# %%
# Create interactive map
route_map = routes_gdf.hvplot(
    geo=True, 
    tiles='CartoLight',
    color='route_type',
    line_width=3
)

# %%
# Time slider
time_slider = pn.widgets.DiscreteSlider(
    name='Time of Day',
    options=['9am', '12pm', '3pm', '6pm']
)

# %%
# Station selector
station_selector = pn.widgets.Select(
    name='SEPTA Station',
    options=['30th St', '40th St Portal', '34th St']
)

# %%
# Dashboard layout
dashboard = pn.Column(
    "# Shade-Optimized Routes to Transit",
    pn.Row(station_selector, time_slider),
    route_map,
    "Shortest route shown in red, shadiest in green"
)

# %%
dashboard.servable()
